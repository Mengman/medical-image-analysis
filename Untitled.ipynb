# %%
# %matplotlib inline

import cv2
from IPython import display
from matplotlib import  pyplot as plt
import mxnet as mx
from mxnet import gluon, nd, image
from gluoncv import utils
from gluoncv.model_zoo import get_model
import numpy as np
import pydicom  as pyd
from os.path import join

# %%
DIR = '/media/tx-deepocean/Data/dataset/test2018/dcm/011145698T100'

# %%
data = pyd.dcmread(join(DIR, '011145698T100_091.dcm'))

# %%
raw = data.pixel_array

# %%
plt.imshow(raw, cmap=plt.cm.gray)
plt.show()

# %%
raw8=np.uint8(cv2.normalize(raw, None, 0, 255, cv2.NORM_MINMAX))

# %%
plt.imshow(raw8,cmap=plt.cm.gray)
plt.show()

# %%
plt.imshow(cv2.equalizeHist(raw8), cmap=plt.cm.gray)

# %%
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
res = np.hstack(( raw8, clahe.apply(raw8) ))
fig=plt.figure(figsize=(18, 18))
plt.imshow(res, cmap=plt.cm.gray)

# %%
def load_scan(slice_files, raise_512=False):
	window_center = -600
	window_width = 1500
	slices = []
	accept = False
	for s in slice_files:
		slices.append(pyd.read_file(s, force=True))
		if (not accept) and raise_512 and slices[-1].pixel_array.shape[0] != 512:
			print ('find 512 scale dicom')
			raise NotImplemented
		accept = True
	img = np.stack([s.pixel_array for s in slices]).astype(np.int16)
	# image = image.astype(np.int16)
	# print 'CT Hu range: ' + str(image.min()) + '--' + str(image.max())

	# Convert to Hounsfield units (HU)
	# intercept = slices[0].RescaleIntercept
	# slope = slices[0].RescaleSlope
	intercept = np.stack([s.RescaleIntercept for s in slices])
	slope = np.stack([s.RescaleSlope for s in slices])
	# if slope != 1:
	img = img.astype(np.float64) * slope[:, np.newaxis, np.newaxis]
	img = img.astype(np.int16)
	img += np.int16(intercept[:, np.newaxis, np.newaxis])
	lungwin = np.array([window_center - window_width // 2., window_center + window_width // 2])
	newimg = (img - lungwin[0]) / (lungwin[1] - lungwin[0])
	newimg[newimg < 0] = 0
	newimg[newimg > 1] = 1
	newimg = (newimg * 255).astype('uint8')

	return newimg

# %%
img = load_scan([join(DIR, '011145698T100_091.dcm')])
print(img.shape)
img = np.squeeze(img)
# Out:
# (1, 512, 512)

# %%
res = np.hstack(( img, clahe.apply(img) ))
fig=plt.figure(figsize=(18, 18))
plt.imshow(res, cmap=plt.cm.gray)

# %%
files = [ join(DIR, '011145698T100_09%d.dcm'%i) for i in range(1, 10)]

# %%
clahe24 = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(4,4))
clahe2004 = cv2.createCLAHE(clipLimit=200.0, tileGridSize=(4,4))
res = np.hstack(( clahe24.apply(img), clahe2004.apply(img) ))
fig=plt.figure(figsize=(18, 18))
plt.imshow(res, cmap=plt.cm.gray)

# %%
clahe216 = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
clahe24 = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(4,4))
res = np.hstack(( clahe216.apply(img), clahe24.apply(img) ))
fig=plt.figure(figsize=(18, 18))
plt.imshow(res, cmap=plt.cm.gray)

# %%
data.RescaleSlope
# Out:
# "1"

# %% [raw]
# data[0x18,0x50]

# %%
raw.shape
# Out:
# (512, 512)

# %%
data[0x28,0x30]
# Out:
# (0028, 0030) Pixel Spacing                       DS: ['0.671', '0.671']

# %%
data[0x18,0x50]
# Out:
# (0018, 0050) Slice Thickness                     DS: "1.0"

# %%
data[0x18,0x88]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-a1e768b254f9> in <module>
# ----> 1 data[0x18,0x88]
#
# ~/miniconda3/envs/dl/lib/python3.7/site-packages/pydicom/dataset.py in __getitem__(self, key)
#     598         else:
#     599             tag = Tag(key)
# --> 600         data_elem = self.tags[tag]
#     601
#     602         if isinstance(data_elem, DataElement):
#
# KeyError: (0018, 0088)
